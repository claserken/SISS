# %%
import pandas as pd

# %%
df = pd.read_parquet('memorized_prompts.parquet')

# %%
df = df.sort_values(by='numdups', ascending=False)

# %%
print(df.head())
# Out:
#                                                  url  \
# 0  https://i.ebayimg.com/thumbs/images/g/Ym8AAOSw...
# 1  https://i.ebayimg.com/thumbs/images/g/Ym8AAOSw...
# 2  https://images.squarespace-cdn.com/content/v1/...
# 3  https://images.squarespace-cdn.com/content/v1/...
# 4  https://i.ebayimg.com/images/g/62MAAOSwILFZsv9...
#
#                                              caption  numdups       index
# 0  Patio Deck Chair Grey Wash Solid Acacia Wood T...  1187676  1708224416
# 1  Patio Deck Chair Grey Wash Solid Acacia Wood T...   570959  1708224416
# 2                                     Buttermere.png   392148   711545904
# 3                                     Buttermere.png   366879   711545904
# 4  NIKE WOMENS AIR SOCK DART DARK STUCCO BLACK WH...   265259  1792285811

# %%
prompts = df['caption'][0:500].tolist()

# %%
print('\n'.join(prompts))
# Out:
# Patio Deck Chair Grey Wash Solid Acacia Wood Tidyard Outdoor Chaise Lounge Chair
# Patio Deck Chair Grey Wash Solid Acacia Wood Tidyard Outdoor Chaise Lounge Chair
# Buttermere.png
# Buttermere.png
# NIKE WOMENS AIR SOCK DART DARK STUCCO BLACK WHITE OLIVE RUNNING 848475 005 SZ 6
# NIKE WOMENS AIR SOCK DART DARK STUCCO BLACK WHITE OLIVE RUNNING 848475 005 SZ 6
# Peugeot 508 Station Wagon 2011 - 2018 Tailored Rubber Boot Mat
# Peugeot 508 Station Wagon 2011 - 2018 Tailored Rubber Boot Mat
# Wall View 002
# Wall View 002
# QR code with A & N Realty contacts
# QR code with A & N Realty contacts
# Go to European Commission website
# Go to European Commission website
# Wall View 002
# Wall View 002
# Buy Snaptic Hi Grade Soft Transparent Back Cover For Htc Desire 620 With Screen Guard online
# Buy Kanvascases Quotes I AM Actually Not Funny Plastic Multicolor Back Cover For Micromax Canvas 5 (e481) online
# Neutrogena Normal Skin Oily Skin Oil Free Facial Moisturiser SPF 15 115 Ml
# ...
